# %%
from __future__ import print_function
import math
import torch
import torch.nn as nn
import torch.nn.init as init

import matplotlib.pyplot as plt
import argparse
# import os
import shutil
import warnings
from copy import deepcopy
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import torchvision
import numpy as np

from prune_layer_bit_new import *
import torch.nn as nn



__all__ = [
    'VGG', 'vgg11', 'vgg11_bn', 'vgg13', 'vgg13_bn', 'vgg16', 'vgg16_bn',
    'vgg19_bn', 'vgg19',
]


class VGG(nn.Module):
    '''
    VGG model 
    '''
    def __init__(self, features):
        super(VGG, self).__init__()
        self.features = features
        self.classifier = nn.Sequential(
            nn.Dropout(),
            PruneLinear(512, 512),
            nn.ReLU(True),
            nn.Dropout(),
            PruneLinear(512, 512),
            nn.ReLU(True),
            PruneLinear(512, 10),
        )
         # Initialize weights
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                m.bias.data.zero_()


    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x


def make_layers(cfg, batch_norm=False):
    layers = []
    in_channels = 3
    for v in cfg:
        if v == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            conv2d = PrunedConv(in_channels, v, kernel_size=3, padding=1)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)

def get_num_correct(pred,labels):
    return pred.argmax(dim=1).eq(labels).sum().item()

def init_weights(m):
    if type(m)==nn.Linear or type(m)==nn.Conv2d:
        torch.nn.init.xavier_uniform_(m.weight)

cfg = {
    'A': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'B': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'D': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'E': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 
          512, 512, 512, 512, 'M'],
}


def Net():
    """VGG 11-layer model (configuration "A")"""
    return VGG(make_layers(cfg['A']))
    
    
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),

])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),

])
train_set=torchvision.datasets.CIFAR10(
    root='~/work/data/Xian/cifar10',
    train=True,
    download=True,
    transform=transform_train)


test_set=torchvision.datasets.CIFAR10(
    root='~/work/data/Xian/cifar10',
    train=False,
    download=True,
    transform=transform_test)



device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device =='cuda':
    print("Run on GPU...")
else:
    print("Run on CPU...")



def train_(train_set,test_set,layer_name, PATH = 'test.pt', set_bit = 1, q = 0, mask_bit_position = [0]*16, epochs = 10):
    torch.manual_seed(1)
    train_loader=torch.utils.data.DataLoader(train_set, batch_size=128, shuffle=False, pin_memory=True,num_workers=2)
    test_loader=torch.utils.data.DataLoader(test_set, batch_size=100, shuffle=False, pin_memory=True,num_workers=2)

    torch.manual_seed(1)
    network= Net().to(device)
    network.apply(init_weights)
    
    layer_num  = 1
    for n, m in network.named_modules():
        if isinstance(m,PrunedConv):
            if layer_num in layer_name:
                m.set_up(mask_bit_position = mask_bit_position,q = q,set_bit = set_bit)
            layer_num +=1
        if isinstance(m,PruneLinear):
            if layer_num in layer_name:
                m.set_up(mask_bit_position = mask_bit_position,q = q,set_bit = set_bit)
            layer_num +=1                

    optimizer = optim.SGD(network.parameters(), lr=0.05, weight_decay=0.0005)
    criterion = torch.nn.CrossEntropyLoss().to(device)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.95)

    acc_train=[]
    acc_test=[]
    acc = 0

    for epoch in range(epochs):
        total_loss = 0
        total_correct = 0
        network.train()
        count_in = 0

        for batch in train_loader: #Get batch
            count_in = count_in + 1
            images,labels = batch
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            #Do bit maskinn
            layer_num  = 1
            for n, m in network.named_modules():
                if isinstance(m,PrunedConv):
                    if layer_num in layer_name:
                        m.prune_by_percentage()     
                    layer_num +=1
                if isinstance(m,PruneLinear):
                    if layer_num in layer_name:
                        m.prune_by_percentage()
                    layer_num +=1

            
            preds=network(images) #pass batch to network
            correct = get_num_correct(preds, labels)
            loss = criterion(preds,labels) #Calculate loss
            loss.backward() #Calculate gradients
            optimizer.step() #Update weights
            total_correct+=correct
            
        print("epoch: ", epoch,  "total_correct: ", total_correct)
        print("training accuracy: ", total_correct/len(train_set))
        print("loss:  ", loss.item())
        acc_train.append(deepcopy(float(total_correct)/len(train_set)))
        torch.save(network, PATH)
        with torch.no_grad():
            correct_test=0
            for batch_test in test_loader: #Get batch
                images_test,labels_test = batch_test
                images_test, labels_test = images_test.to(device), labels_test.to(device)
                preds_test=network(images_test) #pass batch to network
                correct_test += get_num_correct(preds_test, labels_test)
            print("testing accuracy: ", correct_test / len(test_set))
            if epoch == epochs - 1:
                print(correct_test / len(test_set))
                acc = correct_test / len(test_set) 
            acc_test.append(deepcopy(float(correct_test)/len(test_set)))

        scheduler.step()
        
    return acc

epochs = 50
list_q = [1,5,10]
list_mask = [1]
list_acc = []
list_layers =[9]
for layer_name in list_layers:
    for q in list_q:
        for j in list_mask:
            mask_bit_position = [0]*16
            mask_bit_position[j] = 1
            PATH = ""
            PATH += "VGG11_"
            PATH += "L" + str(layer_name)
            PATH += "q" +str(q)
            PATH += "m" + str(list_mask[0])
            print(PATH)
            acc = train_(train_set,test_set,[layer_name], PATH = PATH, 
                         set_bit = 1, q = q, mask_bit_position = mask_bit_position, epochs = epochs)
            list_acc += [acc]
    print(list_acc)
        
# import pandas as pd
# list_acc = np.array(list_acc).reshape((len(list_layers),-1))
# df = pd.DataFrame (list_acc)
# ## save to xlsx file
# print(df)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Run on GPU...
# VGG11_L9q1m1
# epoch:  0 total_correct:  9368
# training accuracy:  0.18736
# loss:   2.0863795280456543
# testing accuracy:  0.2374
# epoch:  1 total_correct:  14767
# training accuracy:  0.29534
# loss:   1.847133994102478
# testing accuracy:  0.3644
# epoch:  2 total_correct:  19356
# training accuracy:  0.38712
# loss:   1.5708597898483276
# testing accuracy:  0.4287
# epoch:  3 total_correct:  22656
# training accuracy:  0.45312
# loss:   1.446858286857605
# testing accuracy:  0.5049
# epoch:  4 total_correct:  25349
# training accuracy:  0.50698
# loss:   1.3432053327560425
# testing accuracy:  0.5411
# epoch:  5 total_correct:  27937
# training accuracy:  0.55874
# loss:   1.2182865142822266
# testing accuracy:  0.5796
# epoch:  6 total_correct:  29753
# training accuracy:  0.59506
# loss:   1.120903730392456
# testing accuracy:  0.6104
# epoch:  7 total_correct:  31428
# training accuracy:  0.62856
# loss:   0.9917041063308716
# testing accuracy:  0.6495
# epoch:  8 total_correct:  32887
# training accuracy:  0.65774
# loss:   0.8559094667434692
# testing accuracy:  0.6662
# epoch:  9 total_correct:  34159
# training accuracy:  0.68318
# loss:   0.8808469772338867
# testing accuracy:  0.6985
# epoch:  10 total_correct:  35365
# training accuracy:  0.7073
# loss:   0.8011733889579773
# testing accuracy:  0.7086
# epoch:  11 total_correct:  36071
# training accuracy:  0.72142
# loss:   0.7695873975753784
# testing accuracy:  0.7389
# epoch:  12 total_correct:  36957
# training accuracy:  0.73914
# loss:   0.7133203744888306
# testing accuracy:  0.7463
# epoch:  13 total_correct:  37626
# training accuracy:  0.75252
# loss:   0.7113765478134155
# testing accuracy:  0.7354
# epoch:  14 total_correct:  38328
# training accuracy:  0.76656
# loss:   0.7065528631210327
# testing accuracy:  0.7516
# epoch:  15 total_correct:  38894
# training accuracy:  0.77788
# loss:   0.7818425297737122
# testing accuracy:  0.7523
# epoch:  16 total_correct:  39390
# training accuracy:  0.7878
# loss:   0.6576467752456665
# testing accuracy:  0.7681
# epoch:  17 total_correct:  39959
# training accuracy:  0.79918
# loss:   0.6159929037094116
# testing accuracy:  0.7694
# epoch:  18 total_correct:  40402
# training accuracy:  0.80804
# loss:   0.5528689026832581
# testing accuracy:  0.7838
# epoch:  19 total_correct:  40655
# training accuracy:  0.8131
# loss:   0.5571198463439941
# testing accuracy:  0.7966
# epoch:  20 total_correct:  41064
# training accuracy:  0.82128
# loss:   0.5213531255722046
# testing accuracy:  0.7955
# epoch:  21 total_correct:  41339
# training accuracy:  0.82678
# loss:   0.454307496547699
# testing accuracy:  0.8023
# epoch:  22 total_correct:  41676
# training accuracy:  0.83352
# loss:   0.5180350542068481
# testing accuracy:  0.7866
# epoch:  23 total_correct:  42031
# training accuracy:  0.84062
# loss:   0.4055570662021637
# testing accuracy:  0.8156
# epoch:  24 total_correct:  42250
# training accuracy:  0.845
# loss:   0.4190676212310791
# testing accuracy:  0.8155
# epoch:  25 total_correct:  42570
# training accuracy:  0.8514
# loss:   0.4127027988433838
# testing accuracy:  0.8041
# epoch:  26 total_correct:  42865
# training accuracy:  0.8573
# loss:   0.4794936180114746
# testing accuracy:  0.8196
# epoch:  27 total_correct:  43110
# training accuracy:  0.8622
# loss:   0.39746910333633423
# testing accuracy:  0.8259
# epoch:  28 total_correct:  43367
# training accuracy:  0.86734
# loss:   0.3603193163871765
# testing accuracy:  0.8275
# epoch:  29 total_correct:  43546
# training accuracy:  0.87092
# loss:   0.3218652904033661
# testing accuracy:  0.8322
# epoch:  30 total_correct:  43593
# training accuracy:  0.87186
# loss:   0.3761020302772522
# testing accuracy:  0.8204
# epoch:  31 total_correct:  43767
# training accuracy:  0.87534
# loss:   0.3153206408023834
# testing accuracy:  0.8303
# epoch:  32 total_correct:  44085
# training accuracy:  0.8817
# loss:   0.28663110733032227
# testing accuracy:  0.8358
# epoch:  33 total_correct:  44311
# training accuracy:  0.88622
# loss:   0.2781447172164917
# testing accuracy:  0.8347
# epoch:  34 total_correct:  44460
# training accuracy:  0.8892
# loss:   0.27496010065078735
# testing accuracy:  0.8321
# epoch:  35 total_correct:  44579
# training accuracy:  0.89158
# loss:   0.2908908724784851
# testing accuracy:  0.842
# epoch:  36 total_correct:  44799
# training accuracy:  0.89598
# loss:   0.2489805519580841
# testing accuracy:  0.8421
# epoch:  37 total_correct:  44879
# training accuracy:  0.89758
# loss:   0.2791677713394165
# testing accuracy:  0.8411
# epoch:  38 total_correct:  45008
# training accuracy:  0.90016
# loss:   0.2243005931377411
# testing accuracy:  0.8496
# epoch:  39 total_correct:  45221
# training accuracy:  0.90442
# loss:   0.19512253999710083
# testing accuracy:  0.8448
# epoch:  40 total_correct:  45397
# training accuracy:  0.90794
# loss:   0.17079584300518036
# testing accuracy:  0.8495
# epoch:  41 total_correct:  45421
# training accuracy:  0.90842
# loss:   0.1938151866197586
# testing accuracy:  0.8469
# epoch:  42 total_correct:  45619
# training accuracy:  0.91238
# loss:   0.15678542852401733
# testing accuracy:  0.8426
# epoch:  43 total_correct:  45709
# training accuracy:  0.91418
# loss:   0.2906719148159027
# testing accuracy:  0.8419
# epoch:  44 total_correct:  45820
# training accuracy:  0.9164
# loss:   0.12885382771492004
# testing accuracy:  0.8513
# epoch:  45 total_correct:  45863
# training accuracy:  0.91726
# loss:   0.14547540247440338
# testing accuracy:  0.85
# epoch:  46 total_correct:  45954
# training accuracy:  0.91908
# loss:   0.1387578248977661
# testing accuracy:  0.8526
# epoch:  47 total_correct:  46101
# training accuracy:  0.92202
# loss:   0.19252276420593262
# testing accuracy:  0.8498
# epoch:  48 total_correct:  46135
# training accuracy:  0.9227
# loss:   0.19569267332553864
# testing accuracy:  0.8531
# epoch:  49 total_correct:  46262
# training accuracy:  0.92524
# loss:   0.16460296511650085
# testing accuracy:  0.8488
# 0.8488
# VGG11_L9q5m1
# epoch:  0 total_correct:  4836
# training accuracy:  0.09672
# loss:   2.3049192428588867
# testing accuracy:  0.1
# epoch:  1 total_correct:  4851
# training accuracy:  0.09702
# loss:   2.3040149211883545
# testing accuracy:  0.097
# epoch:  2 total_correct:  4848
# training accuracy:  0.09696
# loss:   2.305432081222534
# testing accuracy:  0.1017
# epoch:  3 total_correct:  4858
# training accuracy:  0.09716
# loss:   2.303396224975586
# testing accuracy:  0.1009
# epoch:  4 total_correct:  4798
# training accuracy:  0.09596
# loss:   2.304713726043701
# testing accuracy:  0.1042
# epoch:  5 total_correct:  4950
# training accuracy:  0.099
# loss:   2.302865505218506
# testing accuracy:  0.0965
# epoch:  6 total_correct:  4952
# training accuracy:  0.09904
# loss:   2.3040716648101807
# testing accuracy:  0.1
# epoch:  7 total_correct:  4884
# training accuracy:  0.09768
# loss:   2.3048150539398193
# testing accuracy:  0.0995
# epoch:  8 total_correct:  4983
# training accuracy:  0.09966
# loss:   2.3029322624206543
# testing accuracy:  0.0993
# epoch:  9 total_correct:  4945
# training accuracy:  0.0989
# loss:   2.3032283782958984
# testing accuracy:  0.1002
# epoch:  10 total_correct:  4961
# training accuracy:  0.09922
# loss:   2.302150249481201
# testing accuracy:  0.1
# epoch:  11 total_correct:  4804
# training accuracy:  0.09608
# loss:   2.3032002449035645
# testing accuracy:  0.1017
# epoch:  12 total_correct:  4886
# training accuracy:  0.09772
# loss:   2.3016161918640137
# testing accuracy:  0.1039
# epoch:  13 total_correct:  4859
# training accuracy:  0.09718
# loss:   2.3043737411499023
# testing accuracy:  0.0972
# epoch:  14 total_correct:  4898
# training accuracy:  0.09796
# loss:   2.3031718730926514
# testing accuracy:  0.1026
# epoch:  15 total_correct:  4781
# training accuracy:  0.09562
# loss:   2.302590847015381
# testing accuracy:  0.0984
# epoch:  16 total_correct:  4817
# training accuracy:  0.09634
# loss:   2.3032302856445312
# testing accuracy:  0.0989
# epoch:  17 total_correct:  4931
# training accuracy:  0.09862
# loss:   2.30253267288208
# testing accuracy:  0.0987
# epoch:  18 total_correct:  5020
# training accuracy:  0.1004
# loss:   2.3024632930755615
# testing accuracy:  0.1026
# epoch:  19 total_correct:  4889
# training accuracy:  0.09778
# loss:   2.30259108543396
# testing accuracy:  0.1012
# epoch:  20 total_correct:  4967
# training accuracy:  0.09934
# loss:   2.302579402923584
# testing accuracy:  0.102
# epoch:  21 total_correct:  4948
# training accuracy:  0.09896
# loss:   2.302929401397705
# testing accuracy:  0.1005
# epoch:  22 total_correct:  4968
# training accuracy:  0.09936
# loss:   2.3030803203582764
# testing accuracy:  0.1035
# epoch:  23 total_correct:  4887
# training accuracy:  0.09774
# loss:   2.303291082382202
# testing accuracy:  0.0973
# epoch:  24 total_correct:  5034
# training accuracy:  0.10068
# loss:   2.3021886348724365
# testing accuracy:  0.103
# epoch:  25 total_correct:  4864
# training accuracy:  0.09728
# loss:   2.3035359382629395
# testing accuracy:  0.1073
# epoch:  26 total_correct:  4957
# training accuracy:  0.09914
# loss:   2.3015377521514893
# testing accuracy:  0.0995
# epoch:  27 total_correct:  4996
# training accuracy:  0.09992
# loss:   2.301466703414917
# testing accuracy:  0.0974
# epoch:  28 total_correct:  4944
# training accuracy:  0.09888
# loss:   2.3028228282928467
# testing accuracy:  0.0943
# epoch:  29 total_correct:  4962
# training accuracy:  0.09924
# loss:   2.3031911849975586
# testing accuracy:  0.0983
# epoch:  30 total_correct:  4978
# training accuracy:  0.09956
# loss:   2.303010940551758
# testing accuracy:  0.0992
# epoch:  31 total_correct:  5095
# training accuracy:  0.1019
# loss:   2.3038125038146973
# testing accuracy:  0.0972
# epoch:  32 total_correct:  5100
# training accuracy:  0.102
# loss:   2.3037304878234863
# testing accuracy:  0.0996
# epoch:  33 total_correct:  4924
# training accuracy:  0.09848
# loss:   2.3041272163391113
# testing accuracy:  0.0986
# epoch:  34 total_correct:  5027
# training accuracy:  0.10054
# loss:   2.3031461238861084
# testing accuracy:  0.1024
# epoch:  35 total_correct:  4876
# training accuracy:  0.09752
# loss:   2.3037526607513428
# testing accuracy:  0.1015
# epoch:  36 total_correct:  4963
# training accuracy:  0.09926
# loss:   2.3021764755249023
# testing accuracy:  0.101
# epoch:  37 total_correct:  4915
# training accuracy:  0.0983
# loss:   2.3022964000701904
# testing accuracy:  0.1021
# epoch:  38 total_correct:  4925
# training accuracy:  0.0985
# loss:   2.303586959838867
# testing accuracy:  0.1021
# epoch:  39 total_correct:  4843
# training accuracy:  0.09686
# loss:   2.303018569946289
# testing accuracy:  0.1024
# epoch:  40 total_correct:  4810
# training accuracy:  0.0962
# loss:   2.3033556938171387
# testing accuracy:  0.0947
# epoch:  41 total_correct:  4977
# training accuracy:  0.09954
# loss:   2.3034985065460205
# testing accuracy:  0.0995
# epoch:  42 total_correct:  5016
# training accuracy:  0.10032
# loss:   2.302086114883423
# testing accuracy:  0.097
# epoch:  43 total_correct:  5093
# training accuracy:  0.10186
# loss:   2.3043272495269775
# testing accuracy:  0.1003
# epoch:  44 total_correct:  5046
# training accuracy:  0.10092
# loss:   2.302123546600342
# testing accuracy:  0.1011
# epoch:  45 total_correct:  4985
# training accuracy:  0.0997
# loss:   2.3034579753875732
# testing accuracy:  0.1018
# epoch:  46 total_correct:  4828
# training accuracy:  0.09656
# loss:   2.3032760620117188
# testing accuracy:  0.0938
# epoch:  47 total_correct:  5033
# training accuracy:  0.10066
# loss:   2.3030107021331787
# testing accuracy:  0.0983
# epoch:  48 total_correct:  4898
# training accuracy:  0.09796
# loss:   2.302053928375244
# testing accuracy:  0.0977
# epoch:  49 total_correct:  4852
# training accuracy:  0.09704
# loss:   2.3020107746124268
# testing accuracy:  0.0972
# 0.0972
# VGG11_L9q10m1
# epoch:  0 total_correct:  4873
# training accuracy:  0.09746
# loss:   2.3045663833618164
# testing accuracy:  0.1008
# epoch:  1 total_correct:  4839
# training accuracy:  0.09678
# loss:   2.304131269454956
# testing accuracy:  0.097
# epoch:  2 total_correct:  4857
# training accuracy:  0.09714
# loss:   2.304295301437378
# testing accuracy:  0.1015
# epoch:  3 total_correct:  4779
# training accuracy:  0.09558
# loss:   2.303455352783203
# testing accuracy:  0.0989
# epoch:  4 total_correct:  4850
# training accuracy:  0.097
# loss:   2.3034205436706543
# testing accuracy:  0.1013
# epoch:  5 total_correct:  4979
# training accuracy:  0.09958
# loss:   2.302894353866577
# testing accuracy:  0.0968
# epoch:  6 total_correct:  4940
# training accuracy:  0.0988
# loss:   2.303317070007324
# testing accuracy:  0.1021
# epoch:  7 total_correct:  4848
# training accuracy:  0.09696
# loss:   2.304351806640625
# testing accuracy:  0.1004
# epoch:  8 total_correct:  4972
# training accuracy:  0.09944
# loss:   2.3029415607452393
# testing accuracy:  0.0976
# epoch:  9 total_correct:  4973
# training accuracy:  0.09946
# loss:   2.303359270095825
# testing accuracy:  0.1013
# epoch:  10 total_correct:  4882
# training accuracy:  0.09764
# loss:   2.3026390075683594
# testing accuracy:  0.1024
# epoch:  11 total_correct:  4816
# training accuracy:  0.09632
# loss:   2.303292989730835
# testing accuracy:  0.0977
# epoch:  12 total_correct:  4869
# training accuracy:  0.09738
# loss:   2.302464246749878
# testing accuracy:  0.0998
# epoch:  13 total_correct:  4879
# training accuracy:  0.09758
# loss:   2.3037006855010986
# testing accuracy:  0.1023
# epoch:  14 total_correct:  4845
# training accuracy:  0.0969
# loss:   2.302460193634033
# testing accuracy:  0.1043
# epoch:  15 total_correct:  4826
# training accuracy:  0.09652
# loss:   2.3027758598327637
# testing accuracy:  0.1018
# epoch:  16 total_correct:  4781
# training accuracy:  0.09562
# loss:   2.3023838996887207
# testing accuracy:  0.0961
# epoch:  17 total_correct:  4879
# training accuracy:  0.09758
# loss:   2.3017873764038086
# testing accuracy:  0.0964
# epoch:  18 total_correct:  4957
# training accuracy:  0.09914
# loss:   2.3021156787872314
# testing accuracy:  0.1051
# epoch:  19 total_correct:  4937
# training accuracy:  0.09874
# loss:   2.3027031421661377
# testing accuracy:  0.1006
# epoch:  20 total_correct:  4950
# training accuracy:  0.099
# loss:   2.3022916316986084
# testing accuracy:  0.1014
# epoch:  21 total_correct:  4986
# training accuracy:  0.09972
# loss:   2.3024840354919434
# testing accuracy:  0.1001
# epoch:  22 total_correct:  4964
# training accuracy:  0.09928
# loss:   2.3030881881713867
# testing accuracy:  0.1022
# epoch:  23 total_correct:  4857
# training accuracy:  0.09714
# loss:   2.302905559539795
# testing accuracy:  0.0994
# epoch:  24 total_correct:  5010
# training accuracy:  0.1002
# loss:   2.302855968475342
# testing accuracy:  0.1025
# epoch:  25 total_correct:  4821
# training accuracy:  0.09642
# loss:   2.303466320037842
# testing accuracy:  0.101
# epoch:  26 total_correct:  5011
# training accuracy:  0.10022
# loss:   2.3018641471862793
# testing accuracy:  0.0974
# epoch:  27 total_correct:  4943
# training accuracy:  0.09886
# loss:   2.3014628887176514
# testing accuracy:  0.0955
# epoch:  28 total_correct:  4910
# training accuracy:  0.0982
# loss:   2.3019561767578125
# testing accuracy:  0.097
# epoch:  29 total_correct:  4961
# training accuracy:  0.09922
# loss:   2.3027329444885254
# testing accuracy:  0.1001
# epoch:  30 total_correct:  4914
# training accuracy:  0.09828
# loss:   2.303283214569092
# testing accuracy:  0.0967
# epoch:  31 total_correct:  5029
# training accuracy:  0.10058
# loss:   2.3037283420562744
# testing accuracy:  0.0998
# epoch:  32 total_correct:  5075
# training accuracy:  0.1015
# loss:   2.3032312393188477
# testing accuracy:  0.1014
# epoch:  33 total_correct:  4954
# training accuracy:  0.09908
# loss:   2.3034768104553223
# testing accuracy:  0.0976
# epoch:  34 total_correct:  4889
# training accuracy:  0.09778
# loss:   2.302605152130127
# testing accuracy:  0.0988
# epoch:  35 total_correct:  4883
# training accuracy:  0.09766
# loss:   2.303805112838745
# testing accuracy:  0.1007
# epoch:  36 total_correct:  4890
# training accuracy:  0.0978
# loss:   2.301841974258423
# testing accuracy:  0.0991
# epoch:  37 total_correct:  4852
# training accuracy:  0.09704
# loss:   2.3024985790252686
# testing accuracy:  0.0978
# epoch:  38 total_correct:  4903
# training accuracy:  0.09806
# loss:   2.303446054458618
# testing accuracy:  0.0986
# epoch:  39 total_correct:  4807
# training accuracy:  0.09614
# loss:   2.3027467727661133
# testing accuracy:  0.0998
# epoch:  40 total_correct:  4881
# training accuracy:  0.09762
# loss:   2.303297519683838
# testing accuracy:  0.1011
# epoch:  41 total_correct:  4924
# training accuracy:  0.09848
# loss:   2.3028063774108887
# testing accuracy:  0.1005
# epoch:  42 total_correct:  5036
# training accuracy:  0.10072
# loss:   2.302170991897583
# testing accuracy:  0.0965
# epoch:  43 total_correct:  4987
# training accuracy:  0.09974
# loss:   2.3041484355926514
# testing accuracy:  0.1001
# epoch:  44 total_correct:  4963
# training accuracy:  0.09926
# loss:   2.302779197692871
# testing accuracy:  0.1027
# epoch:  45 total_correct:  4850
# training accuracy:  0.097
# loss:   2.3032469749450684
# testing accuracy:  0.103
# epoch:  46 total_correct:  4915
# training accuracy:  0.0983
# loss:   2.30338716506958
# testing accuracy:  0.0981
# epoch:  47 total_correct:  4926
# training accuracy:  0.09852
# loss:   2.302410840988159
# testing accuracy:  0.0984
# epoch:  48 total_correct:  4924
# training accuracy:  0.09848
# loss:   2.3022301197052
# testing accuracy:  0.0986
# epoch:  49 total_correct:  4876
# training accuracy:  0.09752
# loss:   2.302103042602539
# testing accuracy:  0.0979
# 0.0979
# [0.8488, 0.0972, 0.0979]

# %%
layer_name = [9]
layer_num = 1
for name, model in network.named_modules():
    if isinstance(model, PrunedConv):
        if layer_num in layer_name:
            weight = model.conv.weight.data.cpu().detach().numpy().reshape(-1)
            print(type(weight))
#             _ = plt.hist(weight, bins=20)
        layer_num +=1
    elif isinstance(model, PruneLinear):
        if layer_num in layer_name:
            weight = model.linear.weight.data.cpu().detach().numpy().reshape(-1)
            print(type(weight))
            print(weight)
#             _ = plt.hist(weight, bins=20)
        layer_num +=1
    else:
        pass
